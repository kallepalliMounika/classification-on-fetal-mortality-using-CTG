# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\mouni\OneDrive\Desktop\CTG.csv")

# %%
df.head()
# Out:
#      b     e  AC  FM  UC  DL  DS  DP  DR   LB  ...  E  AD  DE  LD  FS  SUSP  \
# 0  240   357   0   0   0   0   0   0   0  120  ... -1  -1  -1  -1   1    -1
# 1    5   632   4   0   4   2   0   0   0  132  ... -1   1  -1  -1  -1    -1
# 2  177   779   2   0   5   2   0   0   0  133  ... -1   1  -1  -1  -1    -1
# 3  411  1192   2   0   6   2   0   0   0  134  ... -1   1  -1  -1  -1    -1
# 4  533  1147   4   0   5   0   0   0   0  132  ... -1  -1  -1  -1  -1    -1
#
#    Unnamed: 40  CLASS  Unnamed: 42  NSP
# 0          NaN      9          NaN    2
# 1          NaN      6          NaN    1
# 2          NaN      6          NaN    1
# 3          NaN      6          NaN    1
# 4          NaN      2          NaN    1
#
# [5 rows x 44 columns]

# %%
df=df.drop(["Unnamed: 40","Unnamed: 42"],axis=1)

# %%
df.head()
# Out:
#      b     e  AC  FM  UC  DL  DS  DP  DR   LB  ...  C  D  E  AD  DE  LD  FS  \
# 0  240   357   0   0   0   0   0   0   0  120  ... -1 -1 -1  -1  -1  -1   1
# 1    5   632   4   0   4   2   0   0   0  132  ... -1 -1 -1   1  -1  -1  -1
# 2  177   779   2   0   5   2   0   0   0  133  ... -1 -1 -1   1  -1  -1  -1
# 3  411  1192   2   0   6   2   0   0   0  134  ... -1 -1 -1   1  -1  -1  -1
# 4  533  1147   4   0   5   0   0   0   0  132  ... -1 -1 -1  -1  -1  -1  -1
#
#    SUSP  CLASS  NSP
# 0    -1      9    2
# 1    -1      6    1
# 2    -1      6    1
# 3    -1      6    1
# 4    -1      2    1
#
# [5 rows x 42 columns]

# %%
df.sample(10)
# Out:
#          b     e  AC  FM  UC  DL  DS  DP  DR   LB  ...  C  D  E  AD  DE  LD  \
# 912   2335  3199   4   0   4   1   0   0   0  146  ... -1 -1 -1  -1  -1  -1
# 1919   682  1614   2   1   7   4   0   0   0  140  ... -1 -1 -1   1  -1  -1
# 39      26  1014   9  54   5   0   0   0   0  115  ... -1 -1 -1  -1  -1  -1
# 1205  3073  3540   0   0   3   0   0   0   0  143  ... -1 -1 -1  -1  -1  -1
# 1867  1473  2230   6   0   0   2   0   0   0  138  ... -1 -1 -1   1  -1  -1
# 1929  2872  3593   0   3   6   3   0   1   0  140  ... -1 -1 -1  -1   1  -1
# 1022   289   824   1   0   3   0   0   0   0  135  ... -1 -1 -1  -1  -1  -1
# 196    317   930   0   0   3   0   0   0   0  150  ... -1 -1  1  -1  -1  -1
# 1925  1760  2694   0   3   5   4   0   0   0  140  ... -1 -1 -1  -1   1  -1
# 1759   132   905   2   0   1   8   0   0   0  120  ... -1 -1 -1   1  -1  -1
#
#       FS  SUSP  CLASS  NSP
# 912   -1    -1      2    1
# 1919  -1    -1      6    1
# 39    -1    -1      2    1
# ...

# %%
df.columns
# Out:
# Index(['b', 'e', 'AC', 'FM', 'UC', 'DL', 'DS', 'DP', 'DR', 'LB', 'AC.1',
#        'FM.1', 'UC.1', 'DL.1', 'DS.1', 'DP.1', 'ASTV', 'MSTV', 'ALTV', 'MLTV',
#        'Width', 'Min', 'Max', 'Nmax', 'Nzeros', 'Mode', 'Mean', 'Median',
#        'Variance', 'Tendency', 'A', 'B', 'C', 'D', 'E', 'AD', 'DE', 'LD', 'FS',
#        'SUSP', 'CLASS', 'NSP'],
#       dtype='object')

# %%
df.shape
# Out:
# (2126, 42)

# %%
df.isnull().sum()
# Out:
# b           0
# e           0
# AC          0
# FM          0
# UC          0
# DL          0
# DS          0
# DP          0
# DR          0
# LB          0
# AC.1        0
# FM.1        0
# UC.1        0
# DL.1        0
# DS.1        0
# DP.1        0
# ASTV        0
# MSTV        0
# ALTV        0
# MLTV        0
# Width       0
# Min         0
# Max         0
# Nmax        0
# Nzeros      0
# Mode        0
# Mean        0
# Median      0
# Variance    0
# Tendency    0
# A           0
# B           0
# C           0
# D           0
# E           0
# AD          0
# DE          0
# LD          0
# FS          0
# SUSP        0
# CLASS       0
# NSP         0
# dtype: int64

# %%
df=df.dropna()

# %%
df.isnull().sum()
# Out:
# b           0
# e           0
# AC          0
# FM          0
# UC          0
# DL          0
# DS          0
# DP          0
# DR          0
# LB          0
# AC.1        0
# FM.1        0
# UC.1        0
# DL.1        0
# DS.1        0
# DP.1        0
# ASTV        0
# MSTV        0
# ALTV        0
# MLTV        0
# Width       0
# Min         0
# Max         0
# Nmax        0
# Nzeros      0
# Mode        0
# Mean        0
# Median      0
# Variance    0
# Tendency    0
# A           0
# B           0
# C           0
# D           0
# E           0
# AD          0
# DE          0
# LD          0
# FS          0
# SUSP        0
# CLASS       0
# NSP         0
# dtype: int64

# %%
df.dtypes
# Out:
# b             int64
# e             int64
# AC            int64
# FM            int64
# UC            int64
# DL            int64
# DS            int64
# DP            int64
# DR            int64
# LB            int64
# AC.1        float64
# FM.1        float64
# UC.1        float64
# DL.1        float64
# DS.1        float64
# DP.1        float64
# ASTV          int64
# MSTV        float64
# ALTV          int64
# MLTV        float64
# Width         int64
# Min           int64
# Max           int64
# Nmax          int64
# Nzeros        int64
# Mode          int64
# Mean          int64
# Median        int64
# Variance      int64
# Tendency      int64
# A             int64
# B             int64
# C             int64
# D             int64
# E             int64
# AD            int64
# DE            int64
# LD            int64
# FS            int64
# SUSP          int64
# CLASS         int64
# NSP           int64
# dtype: object

# %%
#Distribution of the Target Variable
sns.set_style('darkgrid')
plt.figure(figsize = (10,5))
sns.countplot(df['NSP'], alpha = 1, palette= ['aquamarine','magenta','mediumblue'])
plt.title('Target Variable NSP classifications')
plt.ylabel('Patients')
plt.show()

# %%
df.hist(bins=50, figsize=(20,20))
plt.show()

# %%
histogram_min = df.groupby(['Max','NSP']).Max.count().unstack()
pl = histogram_min.plot(kind = 'bar', stacked =True,
                       color = ['aquamarine','magenta','mediumblue'],
                       alpha = .5, figsize = (20,10))
pl.set_xlabel('histogram min FHR',fontsize=20)
pl.locator_params(axis='x',nbins=10)
pl.legend(fontsize=20)
pl.set_ylabel('frequency',fontsize=20)
pl.set_title('Fetal Health by Max histogram FHR',fontsize=20)
plt.show()

# %%
histogram_min = df.groupby(['Min','NSP']).Min.count().unstack()
pl = histogram_min.plot(kind = 'bar', stacked =True,
                       color = ['aquamarine','magenta','mediumblue'],
                       alpha = .5, figsize = (20,10))
pl.set_xlabel('histogram min FHR',fontsize=20)
pl.locator_params(axis='x',nbins=10)
pl.legend(fontsize=20)
pl.set_ylabel('frequency',fontsize=20)
pl.set_title('Fetal Health by min histogram FHR',fontsize=20)
plt.show()

# %%
histogram_min = df.groupby(['Mean','NSP']).Mean.count().unstack()
pl = histogram_min.plot(kind = 'bar', stacked =True,
                       color = ['aquamarine','magenta','mediumblue'],
                       alpha = .5, figsize = (20,10))
pl.set_xlabel('histogram min FHR',fontsize=20)
pl.locator_params(axis='x',nbins=10)
pl.legend(fontsize=20)
pl.set_ylabel('frequency',fontsize=20)
pl.set_title('Fetal Health by Mean FHR',fontsize=20)
plt.show()

# %%
histogram_min = df.groupby(['Width','NSP']).Width.count().unstack()
pl = histogram_min.plot(kind = 'bar', stacked =True,
                       color = ['aquamarine','magenta','mediumblue'],
                       alpha = .5, figsize = (20,10))
pl.set_xlabel('histogram min FHR',fontsize=20)
pl.locator_params(axis='x',nbins=10)
pl.legend(fontsize=20)
pl.set_ylabel('frequency',fontsize=20)
pl.set_title('Fetal Health by Width histogram FHR',fontsize=20)
plt.show()

# %%
# Boxplot of uterine contractions over per sever deceleration of FHR
plt.figure(figsize = (10,10))
sns.boxplot(x = 'DS', 
            y ='UC',
            data = df, 
            palette = 'Spectral').set_title('severe_decelerations vs uterine contractions')
plt.xticks(rotation='vertical')
plt.show()

# %%
#Histogram showing the distribution of severe deceleration in the dataset
df['DS'].hist(bins=30,figsize=(6,6))
# Out:
# <AxesSubplot:>

# %%
#boxplot of foetal health vs sever deceleration
plt.figure(figsize = (10,10))
sns.barplot(x = 'NSP', 
            y ='DS',
            data = df, 
            palette = 'Spectral').set_title('severe_decelerations vs fetal_heatlh')
plt.xticks(rotation='vertical')
plt.show()

# %%
df.describe()
# Out:
#                  b            e           AC           FM           UC  \
# count  2126.000000  2126.000000  2126.000000  2126.000000  2126.000000
# mean    878.439793  1702.877234     2.722484     7.241298     3.659925
# std     894.084748   930.919143     3.560850    37.125309     2.847094
# min       0.000000   287.000000     0.000000     0.000000     0.000000
# 25%      55.000000  1009.000000     0.000000     0.000000     1.000000
# 50%     538.000000  1241.000000     1.000000     0.000000     3.000000
# 75%    1521.000000  2434.750000     4.000000     2.000000     5.000000
# max    3296.000000  3599.000000    26.000000   564.000000    23.000000
#
#                 DL           DS           DP      DR           LB  ...  \
# count  2126.000000  2126.000000  2126.000000  2126.0  2126.000000  ...
# mean      1.570085     0.003293     0.126058     0.0   133.303857  ...
# std       2.499229     0.057300     0.464361     0.0     9.840844  ...
# ...

# %%
df.corr()
# Out:
#                  b         e        AC        FM        UC        DL  \
# b         1.000000  0.944912 -0.038359 -0.133849  0.225595  0.091783
# e         0.944912  1.000000  0.071572 -0.119249  0.386856  0.163257
# AC       -0.038359  0.071572  1.000000  0.053956  0.212100 -0.011350
# FM       -0.133849 -0.119249  0.053956  1.000000 -0.036626  0.076283
# UC        0.225595  0.386856  0.212100 -0.036626  1.000000  0.339484
# DL        0.091783  0.163257 -0.011350  0.076283  0.339484  1.000000
# DS        0.063977  0.068221 -0.039341 -0.010328  0.018405  0.121617
# DP        0.091688  0.111917 -0.110317  0.205337  0.152395  0.294068
# DR             NaN       NaN       NaN       NaN       NaN       NaN
# LB       -0.020400 -0.013979 -0.077967 -0.033305 -0.127722 -0.155908
# AC.1     -0.011703  0.019501  0.913095  0.053992  0.102231 -0.082372
# FM.1     -0.135153 -0.142850  0.028627  0.936168 -0.068591  0.047945
# UC.1      0.302066  0.315324  0.082772 -0.054367  0.833145  0.273096
# ...

# %%
matrix = df.corr().round(2)
sns.heatmap(matrix, annot=True)
plt.show()
sns.set(rc={'figure.figsize':(35,35)})

# %%
X=df[['LB', 'AC', 'FM', 'UC', 'DL',
       'DS', 'DP', 'DR']]
Y=df[["NSP"]]

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler
Scaler=StandardScaler()
X=Scaler.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,Y,test_size=0.3,random_state=42)

# %% [markdown]
# ## Support Vector Machine

# %%
from sklearn.svm import SVC
svm_clf=SVC(kernel="poly",degree=6,coef0=5,gamma=0.1)
svm_clf=svm_clf.fit(X_train,y_train)
y_pred=svm_clf.predict(X_test)

# %% [markdown]
# ## Calculating different metrics

# %%
from sklearn.metrics import accuracy_score, precision_score, f1_score, recall_score, confusion_matrix

# %%
print(confusion_matrix(y_test,y_pred))
# Out:
# [[470  21   5]
#  [ 30  63   8]
#  [  8   7  26]]

# %%
f1_score(y_test,y_pred,average='weighted')
# Out:
# 0.8735324766763667

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.8761755485893417

# %%
precision_score(y_test,y_pred,average='weighted')
# Out:
# 0.8717148088584419

# %%
recall_score(y_test,y_pred,average="weighted")
# Out:
# 0.8761755485893417

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.93      0.95      0.94       496
#            2       0.69      0.62      0.66       101
#            3       0.67      0.63      0.65        41
#
#     accuracy                           0.88       638
#    macro avg       0.76      0.74      0.75       638
# weighted avg       0.87      0.88      0.87       638

# %%
cf_matrix = metrics.confusion_matrix(y_test,y_pred)
sns.set(rc={'figure.figsize':(7,7)})
ax = sns.heatmap(cf_matrix, annot=True, fmt='g', ax=None, cmap='Blues')
ax.set_xlabel('\nPredicted Values')
ax.set_ylabel('Actual Values ');

# %% [markdown]
# # Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
tree_clf=DecisionTreeClassifier(min_samples_split=6, min_samples_leaf=4, max_depth=6, )
tree_clf=tree_clf.fit(X_train,y_train)
y_pred=tree_clf.predict(X_test)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.8683385579937304

# %%
recall_score(y_test,y_pred,average="weighted")
# Out:
# 0.8683385579937304

# %%
precision_score(y_test,y_pred,average='weighted')
# Out:
# 0.8603398399877494

# %%
from sklearn import metrics
import seaborn as sns
cf_matrix = metrics.confusion_matrix(y_test,y_pred)
ax = sns.heatmap(cf_matrix, annot=True, fmt='g', ax=None, cmap='Blues')
ax.set_xlabel('\nPredicted Values')
ax.set_ylabel('Actual Values ');
print(metrics.classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.92      0.95      0.93       496
#            2       0.67      0.50      0.58       101
#            3       0.62      0.78      0.69        41
#
#     accuracy                           0.87       638
#    macro avg       0.74      0.74      0.73       638
# weighted avg       0.86      0.87      0.86       638

# %%
from sklearn.tree import export_graphviz
export_graphviz(
tree_clf, out_file="tree.dot",
feature_names=['LB', 'AC', 'FM', 'UC', 'DL',
       'DS', 'DP', 'DR'],
class_names="NSP",
rounded=True,
filled=True)

# %% [markdown]
# ## Random forest

# %%
# MODELLING

from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

model = RandomForestClassifier()
model.fit(X_train, y_train)

y_pred = model.predict(X_test)

# evaluating the model
print("Training Accuracy :", model.score(X_train, y_train))
print("Testing Accuracy :", model.score(X_test, y_test))

# confusion matrix
cm = confusion_matrix(y_test, y_pred)
print(cm)

# classification report
cr = classification_report(y_test, y_pred)
print(cr)

sns.set(rc={'figure.figsize':(7,7)})
cf_matrix = metrics.confusion_matrix(y_test,y_pred)
ax = sns.heatmap(cf_matrix, annot=True, fmt='g', ax=None, cmap='Blues')
ax.set_xlabel('\nPredicted Values')
ax.set_ylabel('Actual Values ');
# Out:
# Training Accuracy : 0.9751344086021505
# Testing Accuracy : 0.8730407523510971
# [[470  19   7]
#  [ 35  54  12]
#  [  3   5  33]]
#               precision    recall  f1-score   support
#
#            1       0.93      0.95      0.94       496
#            2       0.69      0.53      0.60       101
#            3       0.63      0.80      0.71        41
#
#     accuracy                           0.87       638
#    macro avg       0.75      0.76      0.75       638
# weighted avg       0.87      0.87      0.87       638

# %% [markdown]
# ## Adaboost

# %%
# MODELLING

from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

model1 = AdaBoostClassifier()
model1.fit(X_train, y_train)

y_pred = model.predict(X_test)

# evaluating the model
print("Training Accuracy :", model1.score(X_train, y_train))
print("Testing Accuracy :", model1.score(X_test, y_test))

# confusion matrix
cm = confusion_matrix(y_test, y_pred)
print(cm)

# classification report
cr = classification_report(y_test, y_pred)
print(cr)
sns.set(rc={'figure.figsize':(7,7)})
cf_matrix = metrics.confusion_matrix(y_test,y_pred)
ax = sns.heatmap(cf_matrix, annot=True, fmt='g', ax=None, cmap='Blues')
ax.set_xlabel('\nPredicted Values')
ax.set_ylabel('Actual Values ');
# Out:
# Training Accuracy : 0.8461021505376344
# Testing Accuracy : 0.841692789968652
# [[454  26  16]
#  [ 32  61   8]
#  [  9  10  22]]
#               precision    recall  f1-score   support
#
#            1       0.92      0.92      0.92       496
#            2       0.63      0.60      0.62       101
#            3       0.48      0.54      0.51        41
#
#     accuracy                           0.84       638
#    macro avg       0.67      0.69      0.68       638
# weighted avg       0.84      0.84      0.84       638

# %% [markdown]
# # Using the ensemble technique

# %%
from sklearn.ensemble import VotingClassifier, RandomForestClassifier

# %%
svm_clf=SVC(kernel="poly",degree=6,coef0=5,gamma=0.1,probability=True)
decision_tree=DecisionTreeClassifier(min_samples_split=6, min_samples_leaf=4, max_depth=6)
rnd_clf=RandomForestClassifier()
voting_clf=VotingClassifier(estimators=[("svm",svm_clf),('rf',rnd_clf),("decision_tree",decision_tree)],voting="hard")

# %%
for feature in zip(df.columns, rnd_clf.feature_importances_):
    print(feature)
# Out:
# ('b', 0.32685536627644746)
# ('e', 0.1797060040603239)
# ('AC', 0.11309837659944158)
# ('FM', 0.15135723871361553)
# ('UC', 0.07604392739042783)
# ('DL', 0.0075698682918707485)
# ('DS', 0.14536921866787314)
# ('DP', 0.0)

# %%
features = df.columns
importances = rnd_clf.feature_importances_
indices = np.argsort(importances)

plt.title('Feature Importances')
plt.barh(range(len(indices)), importances[indices], color='b', align='center')
plt.yticks(range(len(indices)), [features[i] for i in indices])
plt.xlabel('Relative Importance')
plt.show()

# %%
voting_clf.fit(X_train,y_train)
# Out:
# VotingClassifier(estimators=[('svm',
#                               SVC(coef0=5, degree=6, gamma=0.1, kernel='poly',
#                                   probability=True)),
#                              ('rf', RandomForestClassifier()),
#                              ('decision_tree',
#                               DecisionTreeClassifier(max_depth=6,
#                                                      min_samples_leaf=4,
#                                                      min_samples_split=6))])

# %%
for clf in (rnd_clf, svm_clf,decision_tree, voting_clf):
    clf.fit(X_train, y_train)
    y_pred = clf.predict(X_test)
    print(clf.__class__.__name__, accuracy_score(y_test, y_pred))
# Out:
# RandomForestClassifier 0.8714733542319749
# SVC 0.8761755485893417
# DecisionTreeClassifier 0.8683385579937304
# VotingClassifier 0.8840125391849529

# %%
sns.set(rc={'figure.figsize':(7,7)})
cf_matrix = metrics.confusion_matrix(y_test,y_pred)
ax = sns.heatmap(cf_matrix, annot=True, fmt='g', ax=None, cmap='Blues')
ax.set_xlabel('\nPredicted Values')
ax.set_ylabel('Actual Values ');
print(metrics.classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.92      0.96      0.94       496
#            2       0.74      0.59      0.66       101
#            3       0.72      0.68      0.70        41
#
#     accuracy                           0.88       638
#    macro avg       0.79      0.75      0.77       638
# weighted avg       0.88      0.88      0.88       638

# %%
from sklearn.ensemble import BaggingClassifier

# %%
bag_clf=BaggingClassifier(DecisionTreeClassifier(),n_estimators=500,n_jobs=-1,max_samples=100, bootstrap=True)

# %%
bag_clf.fit(X_train,y_train)
y_pred=bag_clf.predict(X_test)

# %%
print(accuracy_score(y_test,y_pred))
# Out:
# 0.8667711598746082

# %%
##This accuracy is better than our previous decision tree model
##Therefore, we will again call ensemble technique.

# %%
voting_clf=VotingClassifier(estimators=[("svm",svm_clf),('rf',rnd_clf),("bagging_clf",bag_clf)],voting="hard")

# %%
for clf in (rnd_clf, svm_clf,bag_clf, voting_clf):
    clf.fit(X_train, y_train)
    y_pred = clf.predict(X_test)
    print(clf.__class__.__name__, accuracy_score(y_test, y_pred))
# Out:
# RandomForestClassifier 0.8589341692789969
# SVC 0.8761755485893417
# BaggingClassifier 0.8714733542319749
# VotingClassifier 0.8824451410658307

# %%
sns.set(rc={'figure.figsize':(7,7)})
cf_matrix = metrics.confusion_matrix(y_test,y_pred)
ax = sns.heatmap(cf_matrix, annot=True, fmt='g', ax=None, cmap='Blues')
ax.set_xlabel('\nPredicted Values')
ax.set_ylabel('Actual Values ');
print(metrics.classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.89      0.97      0.93       496
#            2       0.73      0.54      0.62       101
#            3       0.86      0.46      0.60        41
#
#     accuracy                           0.87       638
#    macro avg       0.83      0.66      0.72       638
# weighted avg       0.86      0.87      0.86       638

# %%
bag_clf=BaggingClassifier(DecisionTreeClassifier(),n_estimators=500,n_jobs=-1,max_samples=100, bootstrap=True,oob_score=True)
bag_clf.fit(X_train,y_train)
y_pred=bag_clf.predict(X_test)
print(bag_clf.oob_score_)
sns.set(rc={'figure.figsize':(7,7)})
cf_matrix = metrics.confusion_matrix(y_test,y_pred)
ax = sns.heatmap(cf_matrix, annot=True, fmt='g', ax=None, cmap='Blues')
ax.set_xlabel('\nPredicted Values')
ax.set_ylabel('Actual Values ');
print(metrics.classification_report(y_test,y_pred))
# Out:
# 0.864247311827957
#               precision    recall  f1-score   support
#
#            1       0.89      0.97      0.93       496
#            2       0.74      0.55      0.63       101
#            3       0.87      0.49      0.62        41
#
#     accuracy                           0.87       638
#    macro avg       0.83      0.67      0.73       638
# weighted avg       0.86      0.87      0.86       638

# %%
models = pd.DataFrame({'Model' : ['SVM', 'Decision Tree','Random Forest','Adaboost Classifier','Bagging Classifier','Voting Classifier (Ensembled accuracy)'],'Accuracy Score':[svm_clf.score(X_train, y_train),tree_clf.score(X_train, y_train),model.score(X_train, y_train),model1.score(X_train, y_train),bag_clf.score(X_train, y_train),voting_clf.score(X_train, y_train)]})
models
# Out:
#                                     Model  Accuracy Score
# 0                                     SVM        0.901882
# 1                           Decision Tree        0.889785
# 2                           Random Forest        0.846102
# 3                     Adaboost Classifier        0.846102
# 4                      Bagging Classifier        0.885753
# 5  Voting Classifier (Ensembled accuracy)        0.923387

# %%
models.sort_values(by='Score', ascending=False)
sns.barplot(x='Score', y='Model', data=models)
plt.show()
